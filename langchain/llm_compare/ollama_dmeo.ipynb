# %%
# !uv pip install OpenAI
# Out:
# Using Python 3.13.9 environment at: D:\code\agents\.venv
# Audited 1 package in 31ms

# %%
from openai import OpenAI
import time

# %%
now = time.time()
from openai import OpenAI
client = OpenAI(
    api_key='',
    base_url='http://localhost:11434/v1'
)
# https://platform.openai.com/docs/api-reference/chat/create
completion = client.chat.completions.create(
    model="qwen3:4b",
    messages=[{"role": "user", "content": "Hi, who are you?"}],
    reasoning_effort=None,   # none, low, medium, high
)
print(f"总耗时: {time.time() - now}")
print(completion.choices[0].message.content)
# Out:
# 总耗时: 9.836931705474854
# Hi! I'm Qwen, a large language model developed by Tongyi Lab. I'm here to help with answering questions, writing stories, emails, scripts, coding, logical reasoning, and more. What would you like to do today? 😊

# %%
now = time.time()
from openai import OpenAI
client = OpenAI(
    api_key='',
    base_url='http://localhost:11434/v1'
)
completion = client.chat.completions.create(
    model="gpt-oss:20b",
    messages=[{"role": "user", "content": "Hi, who are you?"}],
    reasoning_effort=None
)
print(f"总耗时: {time.time() - now}")
print(completion.choices[0].message.content)
# Out:
# 总耗时: 15.775559663772583
# I’m ChatGPT, a large language model created by OpenAI. I can help answer questions, explain concepts, brainstorm ideas, write or edit text, and chat about a wide range of topics. How can I assist you today?

# %%
now = time.time()
client = OpenAI(
    api_key='',
    base_url='http://localhost:11434/v1'
)
# https://platform.openai.com/docs/api-reference/chat/create
completion = client.chat.completions.create(
    model="gpt-oss:20b",
    messages=[{"role": "user", "content": "Hi, who are you?"}],
    reasoning_effort="low",  # none, low, medium, high
)
print(f"总耗时: {time.time() - now}")
print(completion.choices[0].message.content)
# Out:
# 总耗时: 4.555221319198608
# Hi! I’m ChatGPT, a virtual assistant powered by AI. I’m here to help answer questions, provide information, brainstorm ideas, or just chat about whatever’s on your mind. How can I assist you today?

# %%
now = time.time()
client = OpenAI(
    api_key='',
    base_url='http://localhost:11434/v1'
)
# https://platform.openai.com/docs/api-reference/chat/create
completion = client.chat.completions.create(
    model="gpt-oss:20b",
    messages=[{"role": "user", "content": "Hi, who are you?"}],
    reasoning_effort="high"  # none, low, medium, high
)
print(f"总耗时: {time.time() - now}")
print(completion.choices[0].message.content)
# Out:
# 总耗时: 13.176315546035767
# Hi there! I’m ChatGPT, a conversational AI created by OpenAI. I can help answer questions, brainstorm ideas, explain concepts, draft emails, write stories, solve math problems, and much more. Think of me as a digital assistant ready to chat and tackle whatever you throw my way. How can I help you today?

# %%
now = time.time()
from openai import OpenAI
client = OpenAI(
    api_key='',
    base_url='http://localhost:11434/v1'
)
# https://platform.openai.com/docs/api-reference/chat/create
completion = client.chat.completions.create(
    model="gemma3:1b",
    messages=[{"role": "user", "content": "Hi, who are you?"}],
    reasoning_effort=None  # none, low, medium, high
)
print(f"总耗时: {time.time() - now}")
print(completion.choices[0].message.content)
# Out:
# 总耗时: 3.3159916400909424
# Hi there! I’m Gemma, a large language model created by the Gemma team at Google DeepMind. I’m an open-weights model, which means I’m widely available for use!
#
# I’m designed to take text and images as input and produce text as output. Basically, I’m here to help you with all sorts of text-based tasks.
#
# How can I help you out today?
